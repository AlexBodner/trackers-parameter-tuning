# %%
# !pip install -q inference
# !pip install -U -q git+https://github.com/roboflow/trackers.git@develop
#!pip install -U -q git+https://github.com/roboflow/trackers.git@03faa93 # Replace <commit_hash_here> with your desired commit hash
# !pip install -q gdown
# !pip install filterpy

# %%
# !mkdir -p SoccerNet_dets
file_id = "1Tx7FuQ90ir0FTlozrsMt4A1C66Q-Dhd6"
output_name = "SoccerNet_tracking_2022_all_dets.zip"
# !cd SoccerNet_dets && gdown $file_id -O $output_name
# !unzip SoccerNet_dets/SoccerNet_tracking_2022_all_dets.zip -d SoccerNet_dets
# !rm SoccerNet_dets/SoccerNet_tracking_2022_all_dets.zip
# !mkdir -p TrackEval/data/gt/SoccerNet_tracking

file_id = "16VVLdez6Axs9FVpdXUEtj_NzyJGaHR9o"
output_name = "SoccerNet_tracking_2022_all_gts.zip"
# !cd TrackEval/data/gt/SoccerNet_tracking && gdown $file_id -O $output_name
# !unzip TrackEval/data/gt/SoccerNet_tracking/SoccerNet_tracking_2022_all_gts.zip -d TrackEval/data/gt/SoccerNet_tracking

file_id = "1sCqpnJ2pWAT9zM91kI2WXDTgoPqtozYQ"
output_name = "SoccerNet_tracking-test__full_seqmap.txt"
# !cd TrackEval/data/gt/SoccerNet_tracking/ && gdown $file_id -O $output_name
