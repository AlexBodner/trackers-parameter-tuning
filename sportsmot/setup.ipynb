# %%
# !pip install filterpy
# !mkdir -p sportsmot_yolox_dets

# %%
file_id = "1F5rHVUdPZvuWnpy_tX1mkURklvxgm7aJ"
output_name = f"yolox_detections_sportsmot.zip"
# !cd sportsmot_yolox_dets && gdown $file_id -O $output_name

zip_path = "sportsmot_yolox_dets/" + output_name
# !unzip {zip_path} -d sportsmot_yolox_dets
# !rm {zip_path}
