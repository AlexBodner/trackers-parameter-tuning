# %%
import os
import itertools
import multiprocessing as mp
import shutil

from concurrent.futures import ProcessPoolExecutor
from collections import defaultdict
from pathlib import Path

import numpy as np
import pandas as pd
import supervision as sv

from trackers import SORTTracker
from trackers.eval import evaluate_mot_sequences


# Detect the MOT17 root that contains `MOT17_yolox_dets`
BASE_DIR = Path.cwd()
while not (BASE_DIR / "MOT17_yolox_dets").exists() and BASE_DIR.parent != BASE_DIR:
    BASE_DIR = BASE_DIR.parent
if not (BASE_DIR / "MOT17_yolox_dets").exists():
    raise FileNotFoundError("Could not find 'MOT17_yolox_dets' in current or parent directories.")

MOT17_DET_ROOT = str((BASE_DIR / "MOT17_yolox_dets").resolve())

# GT aligned to YOLOX val frame ranges (built via `make_mot17_val_half_gt.py`)
MOT17_GT_YOLOX_VAL_ROOT = str((BASE_DIR / "TrackEval" / "data" / "gt" / "MOT17_yolox_val").resolve())
MOT17_GT_TRAINVAL = os.path.join(MOT17_GT_YOLOX_VAL_ROOT, "train_val")
MOT17_VAL_SEQMAP = str((BASE_DIR / "TrackEval" / "data" / "gt" / "MOT17" / "MOT17-val.txt").resolve())

MIN_BOX_AREA = 10
VERTICAL_RATIO_THRESH = 1.6


def get_yolox_detections(frame_id, det_list):
    dets_per_frame = [d for d in det_list if d.split(",")[0] == str(frame_id)]
    dets = []
    for line in dets_per_frame:
        det = line.split(",")  # "frame_no,x1,y1,x2,y2,det_conf"
        x1 = float(det[1])
        y1 = float(det[2])
        x2 = float(det[3])
        y2 = float(det[4])
        conf = float(det[5])
        dets.append([x1, y1, x2, y2, conf])
    return dets


def build_dets_index(det_list):
    dets_by_frame = defaultdict(list)
    for line in det_list:
        frame_id = int(line.split(",")[0])
        dets_by_frame[frame_id].append(line)
    return dets_by_frame


def get_detections_from_dict(frame_id, dets_by_frame):
    dets = []
    for line in dets_by_frame.get(frame_id, []):
        det = line.split(",")
        x1 = float(det[1])
        y1 = float(det[2])
        x2 = float(det[3])
        y2 = float(det[4])
        conf = float(det[5])
        dets.append([x1, y1, x2, y2, conf])
    return dets


def write_mot_output(out_path: str):
    """Convert `MOT17-XX.txt` files into MOT17-server format.

    Creates three files per sequence: `MOT17-XX-{FRCNN,SDP,DPM}.txt`
    and deletes the unsuffixed original, matching the logic used in
    `trackers_ocsort_MOT17_runs.ipynb`.
    """
    out_dir = Path(out_path)

    existing = ["01", "03", "06", "07", "08", "12", "14"]
    missing = ["02", "04", "05", "09", "10", "11", "13"]
    suffixes = ["FRCNN", "SDP", "DPM"]

    # Replicate existing MOT17-XX.txt into 3 suffixed files, then delete original
    for num in existing:
        src = out_dir / f"MOT17-{num}.txt"
        if not src.exists():
            print(f"Missing expected source file: {src}")
            continue

        content = src.read_bytes()
        for suf in suffixes:
            dst = out_dir / f"MOT17-{num}-{suf}.txt"
            dst.write_bytes(content)

        src.unlink()
        print(f"Replicated + removed: {src.name}")

    # Create empty files for missing numbers
    for num in missing:
        for suf in suffixes:
            dst = out_dir / f"MOT17-{num}-{suf}.txt"
            dst.touch(exist_ok=True)

    print("Empty MOT17 server files created for missing sequences.")

# %%
def run_sort_mot17_once(
    split: str,
    lost_track_buffer: int,
    track_activation_threshold: float,
    minimum_consecutive_frames: int,
    minimum_iou_threshold: float,
):
    """Run SORT on one MOT17 split (train/val/test) for a given hyperparameter set."""

    assert split in {"train", "val", "test"}, f"Unsupported split: {split}"

    tracker = SORTTracker(
        lost_track_buffer=lost_track_buffer,
        track_activation_threshold=track_activation_threshold,
        minimum_consecutive_frames=minimum_consecutive_frames,
        minimum_iou_threshold=minimum_iou_threshold,
    )

    det_root = os.path.join(MOT17_DET_ROOT, split)

    outputs_root = "SORT_outputs_MOT17"
    os.makedirs(outputs_root, exist_ok=True)

    save_dir = os.path.join(
        outputs_root,
        f"{split}_L{lost_track_buffer}_A{track_activation_threshold}_"
        f"C{minimum_consecutive_frames}_I{minimum_iou_threshold}",
    )
    os.makedirs(save_dir, exist_ok=True)

    for seq in sorted(os.listdir(det_root)):
        if not seq.endswith(".txt"):
            continue

        tracker.reset()
        seq_name_raw = os.path.splitext(seq)[0]
        # For MOT17-val/train, rename to MOT17-XX-FRCNN so it matches GT + seqmap
        if split in {"train", "val"}:
            seq_name = seq_name_raw.split("_")[0] + "-FRCNN"
        else:
            seq_name = seq_name_raw

        with open(os.path.join(det_root, seq), "r") as f_det:
            det_list = f_det.readlines()
            dets_by_frame = build_dets_index(det_list)

        last_frame = int(det_list[-1].split(",")[0])
        output_lines = []

        for frame_id in range(1, last_frame + 1):
            raw_dets = get_detections_from_dict(frame_id, dets_by_frame)
            if raw_dets:
                raw_dets = np.array(raw_dets)
                dets = sv.Detections(
                    xyxy=raw_dets[:, :4],
                    confidence=raw_dets[:, 4],
                )
            else:
                dets = sv.Detections.empty()

            dets = tracker.update(detections=dets)

            for tid, (left, top, right, bottom) in zip(dets.tracker_id, dets.xyxy):
                if tid == -1:
                    continue

                width = right - left
                height = bottom - top
                vertical = width / max(height, 1e-6) > VERTICAL_RATIO_THRESH

                if width * height > MIN_BOX_AREA and not vertical:
                    output_lines.append(
                        f"{frame_id},{int(tid)},{round(left,1)},{round(top,1)},{round(width,1)},{round(height,1)},-1,-1,-1,-1\n"
                    )

        save_path = os.path.join(save_dir, seq_name + ".txt")
        with open(save_path, "w") as f:
            f.writelines(output_lines)

        print(f"Finished {split} sequence {seq_name} -> {save_path}")

    # For test split, create MOT17 server-compatible outputs
    HOTA = IDF1 = MOTA = None
    if split == "test":
        write_mot_output(save_dir)

    # Evaluate on MOT17-val using YOLOX-aligned GT
    if split == "val":
        try:
            result = evaluate_mot_sequences(
                gt_dir=MOT17_GT_TRAINVAL,
                tracker_dir=save_dir,
                seqmap=MOT17_VAL_SEQMAP,
                metrics=["CLEAR", "HOTA", "Identity"],
            )

            agg = result.to_dict()["aggregate"]
            MOTA = agg["CLEAR"]["MOTA"]
            HOTA = agg["HOTA"]["HOTA"]
            IDF1 = agg["Identity"]["IDF1"]

            print(
                f"split={split} | L:{lost_track_buffer}, A:{track_activation_threshold}, "
                f"C:{minimum_consecutive_frames}, I:{minimum_iou_threshold} -> "
                f"HOTA: {HOTA:.3f}, IDF1: {IDF1:.3f}, MOTA: {MOTA:.3f} (results in {save_dir})"
            )
        except Exception as e:
            print(
                f"split={split} | L:{lost_track_buffer}, A:{track_activation_threshold}, "
                f"C:{minimum_consecutive_frames}, I:{minimum_iou_threshold} -> "
                f"evaluation FAILED ({repr(e)}). Results in {save_dir}"
            )

    return {
        "split": split,
        "lost_track_buffer": lost_track_buffer,
        "track_activation_threshold": track_activation_threshold,
        "minimum_consecutive_frames": minimum_consecutive_frames,
        "minimum_iou_threshold": minimum_iou_threshold,
        "HOTA": HOTA,
        "IDF1": IDF1,
        "MOTA": MOTA,
        "output_dir": save_dir,
    }

# %%
# Define SORT hyperparameter search space for MOT17 (mirroring SportsMOT ranges)

lost_track_buffer_candidates = [10, 30, 60]
track_activation_threshold_candidates = [0.25, 0.5, 0.75, 0.9]
minimum_consecutive_frames_candidates = [2, 3, 5]
minimum_iou_threshold_candidates = [0.05, 0.1, 0.3, 0.5, 0.7]

all_candidate_lists = [
    lost_track_buffer_candidates,
    track_activation_threshold_candidates,
    minimum_consecutive_frames_candidates,
    minimum_iou_threshold_candidates,
]

parameter_combinations = list(itertools.product(*all_candidate_lists))

print(f"Total SORT parameter combinations for MOT17: {len(parameter_combinations)}")
# Out:
# Total SORT parameter combinations for MOT17: 180

# %%
def tune_sort_on_mot17_val_parallel(parameter_combinations):
    """Run SORT over MOT17 **val** for many hyperparameter sets in parallel.

    For each combination, writes MOT-format outputs and, if GT is available
    under `MOT17_GT_TRAINVAL`, also stores HOTA/IDF1/MOTA
    in the returned DataFrame and CSV.
    """

    num_workers = os.cpu_count()
    print(f"Running {len(parameter_combinations)} SORT combinations on MOT17-val with {num_workers} workers")

    ctx = mp.get_context("fork")
    all_results = []

    with ProcessPoolExecutor(max_workers=num_workers, mp_context=ctx) as executor:
        futures = []
        for i, comb in enumerate(parameter_combinations):
            print(f"Submitting combination {i + 1}/{len(parameter_combinations)}")
            (
                lost_track_buffer,
                track_activation_threshold,
                minimum_consecutive_frames,
                minimum_iou_threshold,
            ) = comb
            futures.append(
                executor.submit(
                    run_sort_mot17_once,
                    "val",
                    lost_track_buffer,
                    track_activation_threshold,
                    minimum_consecutive_frames,
                    minimum_iou_threshold,
                )
            )

        for i, f in enumerate(futures):
            try:
                result = f.result()
                all_results.append(result)
                print(f"[{i + 1}/{len(parameter_combinations)}] val combination finished.")
            except Exception as e:
                print(f"[{i + 1}/{len(parameter_combinations)}] val combination FAILED: {repr(e)}")

    df = pd.DataFrame(all_results)
    print("Validation hyperparameter sweep complete. Results stored in 'sort_MOT17_val_tuning_df'.")
    print(df.head())

    if not df.empty:
        df.to_csv("sort_MOT17_val_tuning.csv", index=False)
    else:
        print("Warning: no successful validation runs. Check paths and errors printed above.")

    return df

# %%
# Run the hyperparameter sweep on MOT17-val

sort_MOT17_val_tuning_df = tune_sort_on_mot17_val_parallel(parameter_combinations)

# If HOTA is available, pick best params by HOTA
if (
    not sort_MOT17_val_tuning_df.empty
    and "HOTA" in sort_MOT17_val_tuning_df.columns
    and not sort_MOT17_val_tuning_df["HOTA"].isna().all()
):
    best_idx = sort_MOT17_val_tuning_df["HOTA"].idxmax()
    best_row = sort_MOT17_val_tuning_df.loc[best_idx]
    print("\nBest validation row by HOTA:\n", best_row)

    best_params = dict(
        lost_track_buffer=int(best_row["lost_track_buffer"]),
        track_activation_threshold=float(best_row["track_activation_threshold"]),
        minimum_consecutive_frames=int(best_row["minimum_consecutive_frames"]),
        minimum_iou_threshold=float(best_row["minimum_iou_threshold"]),
    )
    print("\nBest hyperparameters (val):", best_params)
else:
    print(
        "\nNo HOTA column found in 'sort_MOT17_val_tuning_df' – you can still inspect 'output_dir' per row and evaluate externally."
    )
# Out:
# Running 180 SORT combinations on MOT17-val with 10 workers
# Submitting combination 1/180
# Submitting combination 2/180
# Submitting combination 3/180
# Submitting combination 4/180
# Submitting combination 5/180
# Submitting combination 6/180
# Submitting combination 7/180
# Submitting combination 8/180
# Submitting combination 9/180
# Submitting combination 10/180
# Submitting combination 11/180
# Submitting combination 12/180
# Submitting combination 13/180
# Submitting combination 14/180
# Submitting combination 15/180
# Submitting combination 16/180
# Submitting combination 17/180
# Submitting combination 18/180
# Submitting combination 19/180
# Submitting combination 20/180
# Submitting combination 21/180
# Submitting combination 22/180
# Submitting combination 23/180
# Submitting combination 24/180
# Submitting combination 25/180
# Submitting combination 26/180
# Submitting combination 27/180
# Submitting combination 28/180
# Submitting combination 29/180
# Submitting combination 30/180
# Submitting combination 31/180
# Submitting combination 32/180
# Submitting combination 33/180
# Submitting combination 34/180
# Submitting combination 35/180
# Submitting combination 36/180
# Submitting combination 37/180
# Submitting combination 38/180
# Submitting combination 39/180
# Submitting combination 40/180
# Submitting combination 41/180
# Submitting combination 42/180
# Submitting combination 43/180
# Submitting combination 44/180
# Submitting combination 45/180
# Submitting combination 46/180
# Submitting combination 47/180
# Submitting combination 48/180
# Submitting combination 49/180
# Submitting combination 50/180
# Submitting combination 51/180
# Submitting combination 52/180
# Submitting combination 53/180
# Submitting combination 54/180
# Submitting combination 55/180
# Submitting combination 56/180
# Submitting combination 57/180
# Submitting combination 58/180
# Submitting combination 59/180
# Submitting combination 60/180
# Submitting combination 61/180
# Submitting combination 62/180
# Submitting combination 63/180
# Submitting combination 64/180
# Submitting combination 65/180
# Submitting combination 66/180
# Submitting combination 67/180
# Submitting combination 68/180
# Submitting combination 69/180
# Submitting combination 70/180
# Submitting combination 71/180
# Submitting combination 72/180
# Submitting combination 73/180
# Submitting combination 74/180
# Submitting combination 75/180
# Submitting combination 76/180
# Submitting combination 77/180
# Submitting combination 78/180
# Submitting combination 79/180
# Submitting combination 80/180
# Submitting combination 81/180
# Submitting combination 82/180
# Submitting combination 83/180
# Submitting combination 84/180
# Submitting combination 85/180
# Submitting combination 86/180
# Submitting combination 87/180
# Submitting combination 88/180
# Submitting combination 89/180
# Submitting combination 90/180
# Submitting combination 91/180
# Submitting combination 92/180
# Submitting combination 93/180
# Submitting combination 94/180
# Submitting combination 95/180
# Submitting combination 96/180
# Submitting combination 97/180
# Submitting combination 98/180
# Submitting combination 99/180
# Submitting combination 100/180
# Submitting combination 101/180
# Submitting combination 102/180
# Submitting combination 103/180
# Submitting combination 104/180
# Submitting combination 105/180
# Submitting combination 106/180
# Submitting combination 107/180
# Submitting combination 108/180
# Submitting combination 109/180
# Submitting combination 110/180
# Submitting combination 111/180
# Submitting combination 112/180
# Submitting combination 113/180
# Submitting combination 114/180
# Submitting combination 115/180
# Submitting combination 116/180
# Submitting combination 117/180
# Submitting combination 118/180
# Submitting combination 119/180
# Submitting combination 120/180
# Submitting combination 121/180
# Submitting combination 122/180
# Submitting combination 123/180
# Submitting combination 124/180
# Submitting combination 125/180
# Submitting combination 126/180
# Submitting combination 127/180
# Submitting combination 128/180
# Submitting combination 129/180
# Submitting combination 130/180
# Submitting combination 131/180
# Submitting combination 132/180
# Submitting combination 133/180
# Submitting combination 134/180
# Submitting combination 135/180
# Submitting combination 136/180
# Submitting combination 137/180
# Submitting combination 138/180
# Submitting combination 139/180
# Submitting combination 140/180
# Submitting combination 141/180
# Submitting combination 142/180
# Submitting combination 143/180
# Submitting combination 144/180
# Submitting combination 145/180
# Submitting combination 146/180
# Submitting combination 147/180
# Submitting combination 148/180
# Submitting combination 149/180
# Submitting combination 150/180
# Submitting combination 151/180
# Submitting combination 152/180
# Submitting combination 153/180
# Submitting combination 154/180
# Submitting combination 155/180
# Submitting combination 156/180
# Submitting combination 157/180
# Submitting combination 158/180
# Submitting combination 159/180
# Submitting combination 160/180
# Submitting combination 161/180
# Submitting combination 162/180
# Submitting combination 163/180
# Submitting combination 164/180
# Submitting combination 165/180
# Submitting combination 166/180
# Submitting combination 167/180
# Submitting combination 168/180
# Submitting combination 169/180
# Submitting combination 170/180
# Submitting combination 171/180
# Submitting combination 172/180
# Submitting combination 173/180
# Submitting combination 174/180
# Submitting combination 175/180
# Submitting combination 176/180
# Submitting combination 177/180
# Submitting combination 178/180
# Submitting combination 179/180
# Submitting combination 180/180
# Finished val sequence MOT17-02-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C3_I0.7/MOT17-02-FRCNN.txt
# Finished val sequence MOT17-02-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C2_I0.7/MOT17-02-FRCNN.txt
# Finished val sequence MOT17-02-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C3_I0.5/MOT17-02-FRCNN.txt
# Finished val sequence MOT17-02-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C2_I0.5/MOT17-02-FRCNN.txt
# Finished val sequence MOT17-02-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C3_I0.3/MOT17-02-FRCNN.txt
# Finished val sequence MOT17-02-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C2_I0.3/MOT17-02-FRCNN.txt
# Finished val sequence MOT17-02-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C2_I0.05/MOT17-02-FRCNN.txt
# Finished val sequence MOT17-02-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C2_I0.1/MOT17-02-FRCNN.txt
# Finished val sequence MOT17-02-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C3_I0.1/MOT17-02-FRCNN.txt
# Finished val sequence MOT17-02-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C3_I0.05/MOT17-02-FRCNN.txt
# Finished val sequence MOT17-04-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C3_I0.7/MOT17-04-FRCNN.txt
# Finished val sequence MOT17-04-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C2_I0.7/MOT17-04-FRCNN.txt
# Finished val sequence MOT17-05-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C3_I0.7/MOT17-05-FRCNN.txt
# Finished val sequence MOT17-04-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C2_I0.5/MOT17-04-FRCNN.txt
# Finished val sequence MOT17-04-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C3_I0.5/MOT17-04-FRCNN.txt
# Finished val sequence MOT17-05-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C2_I0.7/MOT17-05-FRCNN.txt
# Finished val sequence MOT17-04-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C3_I0.3/MOT17-04-FRCNN.txt
# Finished val sequence MOT17-04-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C2_I0.3/MOT17-04-FRCNN.txt
# Finished val sequence MOT17-04-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C2_I0.05/MOT17-04-FRCNN.txt
# Finished val sequence MOT17-04-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C2_I0.1/MOT17-04-FRCNN.txt
# Finished val sequence MOT17-04-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C3_I0.05/MOT17-04-FRCNN.txt
# Finished val sequence MOT17-09-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C3_I0.7/MOT17-09-FRCNN.txt
# Finished val sequence MOT17-04-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C3_I0.1/MOT17-04-FRCNN.txt
# Finished val sequence MOT17-09-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C2_I0.7/MOT17-09-FRCNN.txt
# Finished val sequence MOT17-05-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C2_I0.5/MOT17-05-FRCNN.txt
# Finished val sequence MOT17-05-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C3_I0.5/MOT17-05-FRCNN.txt
# Finished val sequence MOT17-05-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C3_I0.3/MOT17-05-FRCNN.txt
# Finished val sequence MOT17-05-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C2_I0.3/MOT17-05-FRCNN.txt
# Finished val sequence MOT17-05-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C2_I0.05/MOT17-05-FRCNN.txt
# Finished val sequence MOT17-09-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C2_I0.5/MOT17-09-FRCNN.txt
# Finished val sequence MOT17-09-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C3_I0.5/MOT17-09-FRCNN.txt
# Finished val sequence MOT17-05-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C3_I0.05/MOT17-05-FRCNN.txt
# Finished val sequence MOT17-05-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C2_I0.1/MOT17-05-FRCNN.txt
# Finished val sequence MOT17-05-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C3_I0.1/MOT17-05-FRCNN.txt
# Finished val sequence MOT17-09-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C3_I0.3/MOT17-09-FRCNN.txt
# Finished val sequence MOT17-10-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C3_I0.7/MOT17-10-FRCNN.txt
# Finished val sequence MOT17-09-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C2_I0.3/MOT17-09-FRCNN.txt
# Finished val sequence MOT17-09-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C2_I0.05/MOT17-09-FRCNN.txt
# Finished val sequence MOT17-10-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C2_I0.7/MOT17-10-FRCNN.txt
# Finished val sequence MOT17-09-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C3_I0.05/MOT17-09-FRCNN.txtFinished val sequence MOT17-09-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C3_I0.1/MOT17-09-FRCNN.txt
#
# Finished val sequence MOT17-09-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C2_I0.1/MOT17-09-FRCNN.txt
# Finished val sequence MOT17-10-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C2_I0.5/MOT17-10-FRCNN.txt
# Finished val sequence MOT17-11-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C3_I0.7/MOT17-11-FRCNN.txt
# Finished val sequence MOT17-10-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C3_I0.5/MOT17-10-FRCNN.txt
# Finished val sequence MOT17-11-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C2_I0.7/MOT17-11-FRCNN.txt
# Finished val sequence MOT17-13-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C3_I0.7/MOT17-13-FRCNN.txt
# Finished val sequence MOT17-10-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C3_I0.3/MOT17-10-FRCNN.txt
# Finished val sequence MOT17-10-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C2_I0.3/MOT17-10-FRCNN.txt
# Finished val sequence MOT17-10-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C2_I0.05/MOT17-10-FRCNN.txt
# Finished val sequence MOT17-13-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C2_I0.7/MOT17-13-FRCNN.txt
# Finished val sequence MOT17-10-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C3_I0.05/MOT17-10-FRCNN.txt
# Finished val sequence MOT17-11-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C2_I0.5/MOT17-11-FRCNN.txt
# Finished val sequence MOT17-10-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C3_I0.1/MOT17-10-FRCNN.txt
# Finished val sequence MOT17-10-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C2_I0.1/MOT17-10-FRCNN.txt
# Finished val sequence MOT17-11-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C3_I0.5/MOT17-11-FRCNN.txt
# Finished val sequence MOT17-13-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C2_I0.5/MOT17-13-FRCNN.txt
# Finished val sequence MOT17-11-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C3_I0.3/MOT17-11-FRCNN.txt
# Finished val sequence MOT17-11-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C2_I0.3/MOT17-11-FRCNN.txt
# Finished val sequence MOT17-13-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C3_I0.5/MOT17-13-FRCNN.txt
# Finished val sequence MOT17-11-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C2_I0.05/MOT17-11-FRCNN.txt
# Finished val sequence MOT17-11-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C3_I0.05/MOT17-11-FRCNN.txt
# Finished val sequence MOT17-11-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C3_I0.1/MOT17-11-FRCNN.txt
# Finished val sequence MOT17-13-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C3_I0.3/MOT17-13-FRCNN.txt
# Finished val sequence MOT17-11-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C2_I0.1/MOT17-11-FRCNN.txt
# Finished val sequence MOT17-13-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C2_I0.3/MOT17-13-FRCNN.txt
# Finished val sequence MOT17-13-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C2_I0.05/MOT17-13-FRCNN.txt
# Finished val sequence MOT17-13-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C3_I0.05/MOT17-13-FRCNN.txt
# Finished val sequence MOT17-13-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C3_I0.1/MOT17-13-FRCNN.txt
# Finished val sequence MOT17-13-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C2_I0.1/MOT17-13-FRCNN.txt
# split=val | L:10, A:0.25, C:3, I:0.7 -> HOTA: 0.469, IDF1: 0.471, MOTA: 0.373 (results in SORT_outputs_MOT17/val_L10_A0.25_C3_I0.7)
# split=val | L:10, A:0.25, C:2, I:0.7 -> HOTA: 0.469, IDF1: 0.468, MOTA: 0.370 (results in SORT_outputs_MOT17/val_L10_A0.25_C2_I0.7)
# split=val | L:10, A:0.25, C:2, I:0.5 -> HOTA: 0.472, IDF1: 0.481, MOTA: 0.331 (results in SORT_outputs_MOT17/val_L10_A0.25_C2_I0.5)
# split=val | L:10, A:0.25, C:3, I:0.5 -> HOTA: 0.472, IDF1: 0.484, MOTA: 0.338 (results in SORT_outputs_MOT17/val_L10_A0.25_C3_I0.5)
# split=val | L:10, A:0.25, C:3, I:0.3 -> HOTA: 0.468, IDF1: 0.476, MOTA: 0.308 (results in SORT_outputs_MOT17/val_L10_A0.25_C3_I0.3)
# split=val | L:10, A:0.25, C:2, I:0.3 -> HOTA: 0.469, IDF1: 0.477, MOTA: 0.303 (results in SORT_outputs_MOT17/val_L10_A0.25_C2_I0.3)
# split=val | L:10, A:0.25, C:3, I:0.05 -> HOTA: 0.459, IDF1: 0.472, MOTA: 0.272 (results in SORT_outputs_MOT17/val_L10_A0.25_C3_I0.05)
# split=val | L:10, A:0.25, C:2, I:0.05 -> HOTA: 0.460, IDF1: 0.471, MOTA: 0.270 (results in SORT_outputs_MOT17/val_L10_A0.25_C2_I0.05)
# split=val | L:10, A:0.25, C:3, I:0.1 -> HOTA: 0.459, IDF1: 0.471, MOTA: 0.278 (results in SORT_outputs_MOT17/val_L10_A0.25_C3_I0.1)
# [1/180] val combination finished.
# split=val | L:10, A:0.25, C:2, I:0.1 -> HOTA: 0.459, IDF1: 0.471, MOTA: 0.273 (results in SORT_outputs_MOT17/val_L10_A0.25_C2_I0.1)
# [2/180] val combination finished.
# [3/180] val combination finished.
# [4/180] val combination finished.
# [5/180] val combination finished.
# [6/180] val combination finished.
# [7/180] val combination finished.
# [8/180] val combination finished.
# [9/180] val combination finished.
# [10/180] val combination finished.
# Finished val sequence MOT17-02-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C5_I0.05/MOT17-02-FRCNN.txt
# Finished val sequence MOT17-02-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C5_I0.1/MOT17-02-FRCNN.txt
# Finished val sequence MOT17-02-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C5_I0.7/MOT17-02-FRCNN.txt
# Finished val sequence MOT17-02-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C5_I0.5/MOT17-02-FRCNN.txt
# Finished val sequence MOT17-02-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C5_I0.3/MOT17-02-FRCNN.txt
# Finished val sequence MOT17-02-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C2_I0.5/MOT17-02-FRCNN.txt
# Finished val sequence MOT17-02-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C2_I0.7/MOT17-02-FRCNN.txt
# Finished val sequence MOT17-02-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C2_I0.05/MOT17-02-FRCNN.txt
# Finished val sequence MOT17-02-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C2_I0.3/MOT17-02-FRCNN.txt
# Finished val sequence MOT17-02-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C2_I0.1/MOT17-02-FRCNN.txt
# Finished val sequence MOT17-04-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C5_I0.05/MOT17-04-FRCNN.txt
# Finished val sequence MOT17-04-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C5_I0.3/MOT17-04-FRCNN.txt
# Finished val sequence MOT17-04-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C5_I0.1/MOT17-04-FRCNN.txt
# Finished val sequence MOT17-04-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C5_I0.7/MOT17-04-FRCNN.txt
# Finished val sequence MOT17-04-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C5_I0.5/MOT17-04-FRCNN.txt
# Finished val sequence MOT17-05-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C5_I0.05/MOT17-05-FRCNN.txt
# Finished val sequence MOT17-05-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C5_I0.7/MOT17-05-FRCNN.txt
# Finished val sequence MOT17-05-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C5_I0.1/MOT17-05-FRCNN.txt
# Finished val sequence MOT17-04-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C2_I0.7/MOT17-04-FRCNN.txt
# Finished val sequence MOT17-05-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C5_I0.3/MOT17-05-FRCNN.txt
# Finished val sequence MOT17-04-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C2_I0.5/MOT17-04-FRCNN.txt
# Finished val sequence MOT17-04-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C2_I0.3/MOT17-04-FRCNN.txt
# Finished val sequence MOT17-05-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C5_I0.5/MOT17-05-FRCNN.txt
# Finished val sequence MOT17-09-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C5_I0.05/MOT17-09-FRCNN.txt
# Finished val sequence MOT17-04-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C2_I0.05/MOT17-04-FRCNN.txt
# Finished val sequence MOT17-04-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C2_I0.1/MOT17-04-FRCNN.txtFinished val sequence MOT17-09-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C5_I0.7/MOT17-09-FRCNN.txt
#
# Finished val sequence MOT17-09-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C5_I0.3/MOT17-09-FRCNN.txtFinished val sequence MOT17-09-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C5_I0.1/MOT17-09-FRCNN.txt
#
# Finished val sequence MOT17-05-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C2_I0.7/MOT17-05-FRCNN.txt
# Finished val sequence MOT17-09-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C5_I0.5/MOT17-09-FRCNN.txt
# Finished val sequence MOT17-05-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C2_I0.5/MOT17-05-FRCNN.txt
# Finished val sequence MOT17-05-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C2_I0.3/MOT17-05-FRCNN.txt
# Finished val sequence MOT17-05-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C2_I0.05/MOT17-05-FRCNN.txt
# Finished val sequence MOT17-09-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C2_I0.7/MOT17-09-FRCNN.txt
# Finished val sequence MOT17-05-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C2_I0.1/MOT17-05-FRCNN.txt
# Finished val sequence MOT17-09-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C2_I0.5/MOT17-09-FRCNN.txt
# Finished val sequence MOT17-09-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C2_I0.3/MOT17-09-FRCNN.txt
# Finished val sequence MOT17-10-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C5_I0.7/MOT17-10-FRCNN.txt
# Finished val sequence MOT17-09-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C2_I0.05/MOT17-09-FRCNN.txt
# Finished val sequence MOT17-10-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C5_I0.5/MOT17-10-FRCNN.txtFinished val sequence MOT17-09-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C2_I0.1/MOT17-09-FRCNN.txt
#
# Finished val sequence MOT17-10-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C5_I0.05/MOT17-10-FRCNN.txtFinished val sequence MOT17-10-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C5_I0.3/MOT17-10-FRCNN.txt
#
# Finished val sequence MOT17-10-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C5_I0.1/MOT17-10-FRCNN.txt
# Finished val sequence MOT17-10-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C2_I0.7/MOT17-10-FRCNN.txt
# Finished val sequence MOT17-11-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C5_I0.7/MOT17-11-FRCNN.txt
# Finished val sequence MOT17-10-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C2_I0.5/MOT17-10-FRCNN.txt
# Finished val sequence MOT17-11-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C5_I0.5/MOT17-11-FRCNN.txt
# Finished val sequence MOT17-10-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C2_I0.3/MOT17-10-FRCNN.txt
# Finished val sequence MOT17-11-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C2_I0.7/MOT17-11-FRCNN.txt
# Finished val sequence MOT17-10-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C2_I0.05/MOT17-10-FRCNN.txt
# Finished val sequence MOT17-11-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C5_I0.1/MOT17-11-FRCNN.txtFinished val sequence MOT17-13-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C5_I0.7/MOT17-13-FRCNN.txtFinished val sequence MOT17-11-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C5_I0.3/MOT17-11-FRCNN.txt
#
#
# Finished val sequence MOT17-11-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C5_I0.05/MOT17-11-FRCNN.txt
# Finished val sequence MOT17-10-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C2_I0.1/MOT17-10-FRCNN.txt
# Finished val sequence MOT17-13-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C5_I0.5/MOT17-13-FRCNN.txt
# Finished val sequence MOT17-13-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C2_I0.7/MOT17-13-FRCNN.txt
# Finished val sequence MOT17-11-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C2_I0.5/MOT17-11-FRCNN.txt
# Finished val sequence MOT17-13-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C5_I0.3/MOT17-13-FRCNN.txt
# Finished val sequence MOT17-13-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C5_I0.1/MOT17-13-FRCNN.txt
# Finished val sequence MOT17-13-FRCNN -> SORT_outputs_MOT17/val_L10_A0.25_C5_I0.05/MOT17-13-FRCNN.txt
# Finished val sequence MOT17-11-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C2_I0.3/MOT17-11-FRCNN.txt
# Finished val sequence MOT17-13-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C2_I0.5/MOT17-13-FRCNN.txt
# Finished val sequence MOT17-11-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C2_I0.05/MOT17-11-FRCNN.txtFinished val sequence MOT17-11-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C2_I0.1/MOT17-11-FRCNN.txt
#
# Finished val sequence MOT17-13-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C2_I0.3/MOT17-13-FRCNN.txt
# Finished val sequence MOT17-13-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C2_I0.1/MOT17-13-FRCNN.txt
# Finished val sequence MOT17-13-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C2_I0.05/MOT17-13-FRCNN.txt
# split=val | L:10, A:0.25, C:5, I:0.7 -> HOTA: 0.469, IDF1: 0.477, MOTA: 0.376 (results in SORT_outputs_MOT17/val_L10_A0.25_C5_I0.7)
# split=val | L:10, A:0.25, C:5, I:0.5 -> HOTA: 0.469, IDF1: 0.484, MOTA: 0.342 (results in SORT_outputs_MOT17/val_L10_A0.25_C5_I0.5)split=val | L:10, A:0.5, C:2, I:0.7 -> HOTA: 0.478, IDF1: 0.484, MOTA: 0.406 (results in SORT_outputs_MOT17/val_L10_A0.5_C2_I0.7)
#
# split=val | L:10, A:0.25, C:5, I:0.3 -> HOTA: 0.467, IDF1: 0.479, MOTA: 0.312 (results in SORT_outputs_MOT17/val_L10_A0.25_C5_I0.3)
# split=val | L:10, A:0.25, C:5, I:0.05 -> HOTA: 0.457, IDF1: 0.468, MOTA: 0.279 (results in SORT_outputs_MOT17/val_L10_A0.25_C5_I0.05)
# split=val | L:10, A:0.5, C:2, I:0.5 -> HOTA: 0.485, IDF1: 0.504, MOTA: 0.385 (results in SORT_outputs_MOT17/val_L10_A0.5_C2_I0.5)
# split=val | L:10, A:0.25, C:5, I:0.1 -> HOTA: 0.457, IDF1: 0.472, MOTA: 0.285 (results in SORT_outputs_MOT17/val_L10_A0.25_C5_I0.1)
# [11/180] val combination finished.
# [12/180] val combination finished.
# [13/180] val combination finished.
# [14/180] val combination finished.
# [15/180] val combination finished.
# split=val | L:10, A:0.5, C:2, I:0.3 -> HOTA: 0.481, IDF1: 0.498, MOTA: 0.355 (results in SORT_outputs_MOT17/val_L10_A0.5_C2_I0.3)
# split=val | L:10, A:0.5, C:2, I:0.1 -> HOTA: 0.469, IDF1: 0.486, MOTA: 0.328 (results in SORT_outputs_MOT17/val_L10_A0.5_C2_I0.1)
# split=val | L:10, A:0.5, C:2, I:0.05 -> HOTA: 0.467, IDF1: 0.483, MOTA: 0.328 (results in SORT_outputs_MOT17/val_L10_A0.5_C2_I0.05)
# [16/180] val combination finished.
# [17/180] val combination finished.
# [18/180] val combination finished.
# [19/180] val combination finished.
# [20/180] val combination finished.
# Finished val sequence MOT17-02-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C3_I0.7/MOT17-02-FRCNN.txt
# Finished val sequence MOT17-02-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C3_I0.05/MOT17-02-FRCNN.txt
# Finished val sequence MOT17-02-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C3_I0.5/MOT17-02-FRCNN.txt
# Finished val sequence MOT17-02-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C3_I0.3/MOT17-02-FRCNN.txt
# Finished val sequence MOT17-02-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C3_I0.1/MOT17-02-FRCNN.txt
# Finished val sequence MOT17-02-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C5_I0.7/MOT17-02-FRCNN.txt
# Finished val sequence MOT17-02-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C5_I0.5/MOT17-02-FRCNN.txt
# Finished val sequence MOT17-02-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C5_I0.1/MOT17-02-FRCNN.txt
# Finished val sequence MOT17-02-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C5_I0.05/MOT17-02-FRCNN.txt
# Finished val sequence MOT17-02-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C5_I0.3/MOT17-02-FRCNN.txt
# Finished val sequence MOT17-04-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C3_I0.05/MOT17-04-FRCNN.txt
# Finished val sequence MOT17-04-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C3_I0.7/MOT17-04-FRCNN.txt
# Finished val sequence MOT17-04-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C3_I0.1/MOT17-04-FRCNN.txt
# Finished val sequence MOT17-04-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C3_I0.5/MOT17-04-FRCNN.txt
# Finished val sequence MOT17-04-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C3_I0.3/MOT17-04-FRCNN.txt
# Finished val sequence MOT17-05-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C3_I0.05/MOT17-05-FRCNN.txt
# Finished val sequence MOT17-05-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C3_I0.7/MOT17-05-FRCNN.txt
# Finished val sequence MOT17-04-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C5_I0.7/MOT17-04-FRCNN.txt
# Finished val sequence MOT17-05-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C3_I0.5/MOT17-05-FRCNN.txt
# Finished val sequence MOT17-05-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C3_I0.1/MOT17-05-FRCNN.txtFinished val sequence MOT17-09-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C3_I0.7/MOT17-09-FRCNN.txtFinished val sequence MOT17-04-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C5_I0.5/MOT17-04-FRCNN.txt
#
#
# Finished val sequence MOT17-05-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C3_I0.3/MOT17-05-FRCNN.txtFinished val sequence MOT17-09-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C3_I0.05/MOT17-09-FRCNN.txt
#
# Finished val sequence MOT17-04-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C5_I0.1/MOT17-04-FRCNN.txt
# Finished val sequence MOT17-04-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C5_I0.3/MOT17-04-FRCNN.txt
# Finished val sequence MOT17-04-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C5_I0.05/MOT17-04-FRCNN.txtFinished val sequence MOT17-05-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C5_I0.7/MOT17-05-FRCNN.txt
#
# Finished val sequence MOT17-09-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C3_I0.5/MOT17-09-FRCNN.txt
# Finished val sequence MOT17-09-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C3_I0.1/MOT17-09-FRCNN.txt
# Finished val sequence MOT17-09-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C3_I0.3/MOT17-09-FRCNN.txt
# Finished val sequence MOT17-05-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C5_I0.5/MOT17-05-FRCNN.txt
# Finished val sequence MOT17-09-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C5_I0.7/MOT17-09-FRCNN.txt
# Finished val sequence MOT17-05-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C5_I0.3/MOT17-05-FRCNN.txt
# Finished val sequence MOT17-05-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C5_I0.1/MOT17-05-FRCNN.txt
# Finished val sequence MOT17-05-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C5_I0.05/MOT17-05-FRCNN.txt
# Finished val sequence MOT17-10-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C3_I0.7/MOT17-10-FRCNN.txt
# Finished val sequence MOT17-09-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C5_I0.5/MOT17-09-FRCNN.txt
# Finished val sequence MOT17-10-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C3_I0.05/MOT17-10-FRCNN.txt
# Finished val sequence MOT17-09-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C5_I0.3/MOT17-09-FRCNN.txt
# Finished val sequence MOT17-09-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C5_I0.1/MOT17-09-FRCNN.txt
# Finished val sequence MOT17-09-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C5_I0.05/MOT17-09-FRCNN.txt
# Finished val sequence MOT17-10-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C3_I0.5/MOT17-10-FRCNN.txt
# Finished val sequence MOT17-10-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C5_I0.7/MOT17-10-FRCNN.txt
# Finished val sequence MOT17-10-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C3_I0.3/MOT17-10-FRCNN.txt
# Finished val sequence MOT17-10-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C3_I0.1/MOT17-10-FRCNN.txt
# Finished val sequence MOT17-11-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C3_I0.7/MOT17-11-FRCNN.txt
# Finished val sequence MOT17-11-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C3_I0.05/MOT17-11-FRCNN.txtFinished val sequence MOT17-13-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C3_I0.7/MOT17-13-FRCNN.txt
#
# Finished val sequence MOT17-10-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C5_I0.5/MOT17-10-FRCNN.txt
# Finished val sequence MOT17-11-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C5_I0.7/MOT17-11-FRCNN.txt
# Finished val sequence MOT17-11-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C3_I0.5/MOT17-11-FRCNN.txt
# Finished val sequence MOT17-10-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C5_I0.3/MOT17-10-FRCNN.txt
# Finished val sequence MOT17-11-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C3_I0.1/MOT17-11-FRCNN.txt
# Finished val sequence MOT17-10-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C5_I0.1/MOT17-10-FRCNN.txt
# Finished val sequence MOT17-11-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C3_I0.3/MOT17-11-FRCNN.txt
# Finished val sequence MOT17-10-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C5_I0.05/MOT17-10-FRCNN.txt
# Finished val sequence MOT17-13-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C5_I0.7/MOT17-13-FRCNN.txt
# Finished val sequence MOT17-13-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C3_I0.05/MOT17-13-FRCNN.txt
# Finished val sequence MOT17-13-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C3_I0.5/MOT17-13-FRCNN.txt
# Finished val sequence MOT17-11-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C5_I0.5/MOT17-11-FRCNN.txt
# Finished val sequence MOT17-13-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C3_I0.1/MOT17-13-FRCNN.txt
# Finished val sequence MOT17-13-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C3_I0.3/MOT17-13-FRCNN.txt
# Finished val sequence MOT17-11-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C5_I0.3/MOT17-11-FRCNN.txt
# Finished val sequence MOT17-11-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C5_I0.05/MOT17-11-FRCNN.txt
# Finished val sequence MOT17-11-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C5_I0.1/MOT17-11-FRCNN.txt
# Finished val sequence MOT17-13-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C5_I0.5/MOT17-13-FRCNN.txt
# Finished val sequence MOT17-13-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C5_I0.3/MOT17-13-FRCNN.txt
# Finished val sequence MOT17-13-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C5_I0.05/MOT17-13-FRCNN.txt
# Finished val sequence MOT17-13-FRCNN -> SORT_outputs_MOT17/val_L10_A0.5_C5_I0.1/MOT17-13-FRCNN.txt
# split=val | L:10, A:0.5, C:3, I:0.7 -> HOTA: 0.476, IDF1: 0.484, MOTA: 0.404 (results in SORT_outputs_MOT17/val_L10_A0.5_C3_I0.7)
# split=val | L:10, A:0.5, C:5, I:0.7 -> HOTA: 0.473, IDF1: 0.486, MOTA: 0.395 (results in SORT_outputs_MOT17/val_L10_A0.5_C5_I0.7)
# split=val | L:10, A:0.5, C:3, I:0.05 -> HOTA: 0.467, IDF1: 0.484, MOTA: 0.328 (results in SORT_outputs_MOT17/val_L10_A0.5_C3_I0.05)
# [21/180] val combination finished.
# split=val | L:10, A:0.5, C:3, I:0.5 -> HOTA: 0.484, IDF1: 0.505, MOTA: 0.385 (results in SORT_outputs_MOT17/val_L10_A0.5_C3_I0.5)
# split=val | L:10, A:0.5, C:3, I:0.1 -> HOTA: 0.469, IDF1: 0.487, MOTA: 0.330 (results in SORT_outputs_MOT17/val_L10_A0.5_C3_I0.1)
# [22/180] val combination finished.
# split=val | L:10, A:0.5, C:5, I:0.5 -> HOTA: 0.480, IDF1: 0.503, MOTA: 0.383 (results in SORT_outputs_MOT17/val_L10_A0.5_C5_I0.5)
# split=val | L:10, A:0.5, C:3, I:0.3 -> HOTA: 0.480, IDF1: 0.499, MOTA: 0.355 (results in SORT_outputs_MOT17/val_L10_A0.5_C3_I0.3)
# [23/180] val combination finished.
# [24/180] val combination finished.
# [25/180] val combination finished.
# split=val | L:10, A:0.5, C:5, I:0.3 -> HOTA: 0.478, IDF1: 0.499, MOTA: 0.352 (results in SORT_outputs_MOT17/val_L10_A0.5_C5_I0.3)
# split=val | L:10, A:0.5, C:5, I:0.1 -> HOTA: 0.467, IDF1: 0.486, MOTA: 0.329 (results in SORT_outputs_MOT17/val_L10_A0.5_C5_I0.1)
# split=val | L:10, A:0.5, C:5, I:0.05 -> HOTA: 0.464, IDF1: 0.483, MOTA: 0.329 (results in SORT_outputs_MOT17/val_L10_A0.5_C5_I0.05)
# Finished val sequence MOT17-02-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C2_I0.05/MOT17-02-FRCNN.txt
# [26/180] val combination finished.
# [27/180] val combination finished.
# [28/180] val combination finished.
# [29/180] val combination finished.
# [30/180] val combination finished.
# Finished val sequence MOT17-02-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C2_I0.1/MOT17-02-FRCNN.txt
# Finished val sequence MOT17-02-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C2_I0.3/MOT17-02-FRCNN.txt
# Finished val sequence MOT17-02-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C2_I0.5/MOT17-02-FRCNN.txt
# Finished val sequence MOT17-02-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C2_I0.7/MOT17-02-FRCNN.txt
# Finished val sequence MOT17-02-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C3_I0.7/MOT17-02-FRCNN.txt
# Finished val sequence MOT17-02-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C3_I0.1/MOT17-02-FRCNN.txt
# Finished val sequence MOT17-02-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C3_I0.5/MOT17-02-FRCNN.txt
# Finished val sequence MOT17-02-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C3_I0.05/MOT17-02-FRCNN.txt
# Finished val sequence MOT17-02-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C3_I0.3/MOT17-02-FRCNN.txt
# Finished val sequence MOT17-04-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C2_I0.05/MOT17-04-FRCNN.txt
# Finished val sequence MOT17-04-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C2_I0.1/MOT17-04-FRCNN.txt
# Finished val sequence MOT17-04-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C2_I0.5/MOT17-04-FRCNN.txt
# Finished val sequence MOT17-04-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C2_I0.3/MOT17-04-FRCNN.txt
# Finished val sequence MOT17-04-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C2_I0.7/MOT17-04-FRCNN.txt
# Finished val sequence MOT17-05-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C2_I0.05/MOT17-05-FRCNN.txt
# Finished val sequence MOT17-05-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C2_I0.5/MOT17-05-FRCNN.txt
# Finished val sequence MOT17-05-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C2_I0.1/MOT17-05-FRCNN.txt
# Finished val sequence MOT17-09-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C2_I0.05/MOT17-09-FRCNN.txt
# Finished val sequence MOT17-04-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C3_I0.7/MOT17-04-FRCNN.txt
# Finished val sequence MOT17-05-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C2_I0.7/MOT17-05-FRCNN.txtFinished val sequence MOT17-05-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C2_I0.3/MOT17-05-FRCNN.txt
#
# Finished val sequence MOT17-04-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C3_I0.1/MOT17-04-FRCNN.txt
# Finished val sequence MOT17-04-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C3_I0.5/MOT17-04-FRCNN.txt
# Finished val sequence MOT17-09-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C2_I0.5/MOT17-09-FRCNN.txt
# Finished val sequence MOT17-09-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C2_I0.1/MOT17-09-FRCNN.txt
# Finished val sequence MOT17-04-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C3_I0.05/MOT17-04-FRCNN.txt
# Finished val sequence MOT17-05-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C3_I0.7/MOT17-05-FRCNN.txt
# Finished val sequence MOT17-09-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C2_I0.7/MOT17-09-FRCNN.txt
# Finished val sequence MOT17-09-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C2_I0.3/MOT17-09-FRCNN.txtFinished val sequence MOT17-04-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C3_I0.3/MOT17-04-FRCNN.txt
#
# Finished val sequence MOT17-05-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C3_I0.5/MOT17-05-FRCNN.txt
# Finished val sequence MOT17-05-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C3_I0.1/MOT17-05-FRCNN.txt
# Finished val sequence MOT17-09-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C3_I0.7/MOT17-09-FRCNN.txt
# Finished val sequence MOT17-10-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C2_I0.5/MOT17-10-FRCNN.txt
# Finished val sequence MOT17-10-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C2_I0.05/MOT17-10-FRCNN.txt
# Finished val sequence MOT17-05-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C3_I0.05/MOT17-05-FRCNN.txt
# Finished val sequence MOT17-09-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C3_I0.5/MOT17-09-FRCNN.txt
# Finished val sequence MOT17-05-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C3_I0.3/MOT17-05-FRCNN.txt
# Finished val sequence MOT17-09-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C3_I0.1/MOT17-09-FRCNN.txt
# Finished val sequence MOT17-10-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C2_I0.7/MOT17-10-FRCNN.txt
# Finished val sequence MOT17-10-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C2_I0.1/MOT17-10-FRCNN.txt
# Finished val sequence MOT17-09-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C3_I0.05/MOT17-09-FRCNN.txt
# Finished val sequence MOT17-10-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C2_I0.3/MOT17-10-FRCNN.txt
# Finished val sequence MOT17-10-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C3_I0.7/MOT17-10-FRCNN.txt
# Finished val sequence MOT17-09-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C3_I0.3/MOT17-09-FRCNN.txt
# Finished val sequence MOT17-11-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C2_I0.5/MOT17-11-FRCNN.txt
# Finished val sequence MOT17-11-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C2_I0.05/MOT17-11-FRCNN.txt
# Finished val sequence MOT17-11-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C2_I0.7/MOT17-11-FRCNN.txt
# Finished val sequence MOT17-10-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C3_I0.5/MOT17-10-FRCNN.txt
# Finished val sequence MOT17-11-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C2_I0.1/MOT17-11-FRCNN.txt
# Finished val sequence MOT17-10-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C3_I0.1/MOT17-10-FRCNN.txt
# Finished val sequence MOT17-13-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C2_I0.7/MOT17-13-FRCNN.txt
# Finished val sequence MOT17-13-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C2_I0.5/MOT17-13-FRCNN.txt
# Finished val sequence MOT17-11-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C2_I0.3/MOT17-11-FRCNN.txt
# Finished val sequence MOT17-13-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C2_I0.05/MOT17-13-FRCNN.txt
# Finished val sequence MOT17-11-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C3_I0.7/MOT17-11-FRCNN.txt
# Finished val sequence MOT17-10-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C3_I0.05/MOT17-10-FRCNN.txt
# Finished val sequence MOT17-10-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C3_I0.3/MOT17-10-FRCNN.txt
# Finished val sequence MOT17-13-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C2_I0.1/MOT17-13-FRCNN.txt
# Finished val sequence MOT17-11-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C3_I0.5/MOT17-11-FRCNN.txt
# Finished val sequence MOT17-13-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C3_I0.7/MOT17-13-FRCNN.txt
# Finished val sequence MOT17-13-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C2_I0.3/MOT17-13-FRCNN.txt
# Finished val sequence MOT17-11-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C3_I0.1/MOT17-11-FRCNN.txt
# Finished val sequence MOT17-13-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C3_I0.5/MOT17-13-FRCNN.txt
# Finished val sequence MOT17-11-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C3_I0.05/MOT17-11-FRCNN.txt
# Finished val sequence MOT17-11-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C3_I0.3/MOT17-11-FRCNN.txt
# Finished val sequence MOT17-13-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C3_I0.1/MOT17-13-FRCNN.txt
# Finished val sequence MOT17-13-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C3_I0.05/MOT17-13-FRCNN.txt
# Finished val sequence MOT17-13-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C3_I0.3/MOT17-13-FRCNN.txt
# split=val | L:10, A:0.75, C:2, I:0.7 -> HOTA: 0.482, IDF1: 0.495, MOTA: 0.415 (results in SORT_outputs_MOT17/val_L10_A0.75_C2_I0.7)
# split=val | L:10, A:0.75, C:2, I:0.05 -> HOTA: 0.482, IDF1: 0.508, MOTA: 0.381 (results in SORT_outputs_MOT17/val_L10_A0.75_C2_I0.05)
# split=val | L:10, A:0.75, C:2, I:0.5 -> HOTA: 0.491, IDF1: 0.518, MOTA: 0.415 (results in SORT_outputs_MOT17/val_L10_A0.75_C2_I0.5)
# [31/180] val combination finished.
# split=val | L:10, A:0.75, C:3, I:0.7 -> HOTA: 0.479, IDF1: 0.493, MOTA: 0.409 (results in SORT_outputs_MOT17/val_L10_A0.75_C3_I0.7)
# split=val | L:10, A:0.75, C:2, I:0.1 -> HOTA: 0.483, IDF1: 0.510, MOTA: 0.384 (results in SORT_outputs_MOT17/val_L10_A0.75_C2_I0.1)
# split=val | L:10, A:0.75, C:2, I:0.3 -> HOTA: 0.493, IDF1: 0.522, MOTA: 0.400 (results in SORT_outputs_MOT17/val_L10_A0.75_C2_I0.3)
# [32/180] val combination finished.
# [33/180] val combination finished.
# [34/180] val combination finished.
# [35/180] val combination finished.
# split=val | L:10, A:0.75, C:3, I:0.5 -> HOTA: 0.489, IDF1: 0.517, MOTA: 0.413 (results in SORT_outputs_MOT17/val_L10_A0.75_C3_I0.5)
# split=val | L:10, A:0.75, C:3, I:0.1 -> HOTA: 0.481, IDF1: 0.508, MOTA: 0.382 (results in SORT_outputs_MOT17/val_L10_A0.75_C3_I0.1)
# Finished val sequence MOT17-02-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C5_I0.05/MOT17-02-FRCNN.txt
# split=val | L:10, A:0.75, C:3, I:0.3 -> HOTA: 0.490, IDF1: 0.519, MOTA: 0.395 (results in SORT_outputs_MOT17/val_L10_A0.75_C3_I0.3)
# Finished val sequence MOT17-02-FRCNN -> SORT_outputs_MOT17/val_L10_A0.9_C2_I0.05/MOT17-02-FRCNN.txt
# Finished val sequence MOT17-02-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C5_I0.7/MOT17-02-FRCNN.txt
# Finished val sequence MOT17-02-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C5_I0.5/MOT17-02-FRCNN.txt
# Finished val sequence MOT17-02-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C5_I0.1/MOT17-02-FRCNN.txt
# split=val | L:10, A:0.75, C:3, I:0.05 -> HOTA: 0.481, IDF1: 0.507, MOTA: 0.379 (results in SORT_outputs_MOT17/val_L10_A0.75_C3_I0.05)
# Finished val sequence MOT17-02-FRCNN -> SORT_outputs_MOT17/val_L10_A0.9_C2_I0.1/MOT17-02-FRCNN.txt
# Finished val sequence MOT17-02-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C5_I0.3/MOT17-02-FRCNN.txt
# Finished val sequence MOT17-02-FRCNN -> SORT_outputs_MOT17/val_L10_A0.9_C2_I0.3/MOT17-02-FRCNN.txt
# [36/180] val combination finished.
# [37/180] val combination finished.
# [38/180] val combination finished.
# [39/180] val combination finished.
# [40/180] val combination finished.
# Finished val sequence MOT17-02-FRCNN -> SORT_outputs_MOT17/val_L10_A0.9_C2_I0.5/MOT17-02-FRCNN.txt
# Finished val sequence MOT17-02-FRCNN -> SORT_outputs_MOT17/val_L10_A0.9_C2_I0.7/MOT17-02-FRCNN.txt
# Finished val sequence MOT17-04-FRCNN -> SORT_outputs_MOT17/val_L10_A0.9_C2_I0.05/MOT17-04-FRCNN.txt
# Finished val sequence MOT17-04-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C5_I0.05/MOT17-04-FRCNN.txt
# Finished val sequence MOT17-04-FRCNN -> SORT_outputs_MOT17/val_L10_A0.9_C2_I0.1/MOT17-04-FRCNN.txt
# Finished val sequence MOT17-04-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C5_I0.1/MOT17-04-FRCNN.txt
# Finished val sequence MOT17-04-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C5_I0.7/MOT17-04-FRCNN.txt
# Finished val sequence MOT17-05-FRCNN -> SORT_outputs_MOT17/val_L10_A0.9_C2_I0.05/MOT17-05-FRCNN.txt
# Finished val sequence MOT17-04-FRCNN -> SORT_outputs_MOT17/val_L10_A0.9_C2_I0.3/MOT17-04-FRCNN.txt
# Finished val sequence MOT17-04-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C5_I0.5/MOT17-04-FRCNN.txt
# Finished val sequence MOT17-04-FRCNN -> SORT_outputs_MOT17/val_L10_A0.9_C2_I0.5/MOT17-04-FRCNN.txt
# Finished val sequence MOT17-05-FRCNN -> SORT_outputs_MOT17/val_L10_A0.9_C2_I0.1/MOT17-05-FRCNN.txt
# Finished val sequence MOT17-04-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C5_I0.3/MOT17-04-FRCNN.txt
# Finished val sequence MOT17-05-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C5_I0.05/MOT17-05-FRCNN.txt
# Finished val sequence MOT17-09-FRCNN -> SORT_outputs_MOT17/val_L10_A0.9_C2_I0.05/MOT17-09-FRCNN.txt
# Finished val sequence MOT17-04-FRCNN -> SORT_outputs_MOT17/val_L10_A0.9_C2_I0.7/MOT17-04-FRCNN.txt
# Finished val sequence MOT17-05-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C5_I0.7/MOT17-05-FRCNN.txtFinished val sequence MOT17-05-FRCNN -> SORT_outputs_MOT17/val_L10_A0.9_C2_I0.3/MOT17-05-FRCNN.txt
#
# Finished val sequence MOT17-05-FRCNN -> SORT_outputs_MOT17/val_L10_A0.9_C2_I0.5/MOT17-05-FRCNN.txt
# Finished val sequence MOT17-09-FRCNN -> SORT_outputs_MOT17/val_L10_A0.9_C2_I0.1/MOT17-09-FRCNN.txt
# Finished val sequence MOT17-05-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C5_I0.5/MOT17-05-FRCNN.txt
# Finished val sequence MOT17-05-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C5_I0.1/MOT17-05-FRCNN.txt
# Finished val sequence MOT17-10-FRCNN -> SORT_outputs_MOT17/val_L10_A0.9_C2_I0.05/MOT17-10-FRCNN.txt
# Finished val sequence MOT17-09-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C5_I0.05/MOT17-09-FRCNN.txt
# Finished val sequence MOT17-05-FRCNN -> SORT_outputs_MOT17/val_L10_A0.9_C2_I0.7/MOT17-05-FRCNN.txt
# Finished val sequence MOT17-10-FRCNN -> SORT_outputs_MOT17/val_L10_A0.9_C2_I0.1/MOT17-10-FRCNN.txt
# Finished val sequence MOT17-09-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C5_I0.7/MOT17-09-FRCNN.txt
# Finished val sequence MOT17-09-FRCNN -> SORT_outputs_MOT17/val_L10_A0.9_C2_I0.3/MOT17-09-FRCNN.txt
# Finished val sequence MOT17-09-FRCNN -> SORT_outputs_MOT17/val_L10_A0.9_C2_I0.5/MOT17-09-FRCNN.txt
# Finished val sequence MOT17-05-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C5_I0.3/MOT17-05-FRCNN.txt
# Finished val sequence MOT17-09-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C5_I0.5/MOT17-09-FRCNN.txt
# Finished val sequence MOT17-09-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C5_I0.1/MOT17-09-FRCNN.txt
# Finished val sequence MOT17-09-FRCNN -> SORT_outputs_MOT17/val_L10_A0.9_C2_I0.7/MOT17-09-FRCNN.txt
# Finished val sequence MOT17-10-FRCNN -> SORT_outputs_MOT17/val_L10_A0.9_C2_I0.3/MOT17-10-FRCNN.txt
# Finished val sequence MOT17-10-FRCNN -> SORT_outputs_MOT17/val_L10_A0.9_C2_I0.5/MOT17-10-FRCNN.txt
# Finished val sequence MOT17-11-FRCNN -> SORT_outputs_MOT17/val_L10_A0.9_C2_I0.05/MOT17-11-FRCNN.txt
# Finished val sequence MOT17-09-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C5_I0.3/MOT17-09-FRCNN.txtFinished val sequence MOT17-10-FRCNN -> SORT_outputs_MOT17/val_L10_A0.9_C2_I0.7/MOT17-10-FRCNN.txt
#
# Finished val sequence MOT17-13-FRCNN -> SORT_outputs_MOT17/val_L10_A0.9_C2_I0.05/MOT17-13-FRCNN.txtFinished val sequence MOT17-11-FRCNN -> SORT_outputs_MOT17/val_L10_A0.9_C2_I0.1/MOT17-11-FRCNN.txt
#
# Finished val sequence MOT17-10-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C5_I0.7/MOT17-10-FRCNN.txt
# Finished val sequence MOT17-13-FRCNN -> SORT_outputs_MOT17/val_L10_A0.9_C2_I0.1/MOT17-13-FRCNN.txt
# Finished val sequence MOT17-10-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C5_I0.05/MOT17-10-FRCNN.txt
# Finished val sequence MOT17-11-FRCNN -> SORT_outputs_MOT17/val_L10_A0.9_C2_I0.5/MOT17-11-FRCNN.txt
# Finished val sequence MOT17-11-FRCNN -> SORT_outputs_MOT17/val_L10_A0.9_C2_I0.3/MOT17-11-FRCNN.txt
# Finished val sequence MOT17-10-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C5_I0.5/MOT17-10-FRCNN.txt
# Finished val sequence MOT17-11-FRCNN -> SORT_outputs_MOT17/val_L10_A0.9_C2_I0.7/MOT17-11-FRCNN.txt
# Finished val sequence MOT17-13-FRCNN -> SORT_outputs_MOT17/val_L10_A0.9_C2_I0.5/MOT17-13-FRCNN.txt
# Finished val sequence MOT17-13-FRCNN -> SORT_outputs_MOT17/val_L10_A0.9_C2_I0.3/MOT17-13-FRCNN.txt
# Finished val sequence MOT17-10-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C5_I0.1/MOT17-10-FRCNN.txt
# Finished val sequence MOT17-13-FRCNN -> SORT_outputs_MOT17/val_L10_A0.9_C2_I0.7/MOT17-13-FRCNN.txt
# Finished val sequence MOT17-11-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C5_I0.7/MOT17-11-FRCNN.txt
# Finished val sequence MOT17-10-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C5_I0.3/MOT17-10-FRCNN.txt
# Finished val sequence MOT17-11-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C5_I0.05/MOT17-11-FRCNN.txt
# Finished val sequence MOT17-13-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C5_I0.7/MOT17-13-FRCNN.txt
# Finished val sequence MOT17-11-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C5_I0.5/MOT17-11-FRCNN.txt
# Finished val sequence MOT17-11-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C5_I0.1/MOT17-11-FRCNN.txt
# Finished val sequence MOT17-13-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C5_I0.05/MOT17-13-FRCNN.txt
# Finished val sequence MOT17-11-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C5_I0.3/MOT17-11-FRCNN.txt
# Finished val sequence MOT17-13-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C5_I0.5/MOT17-13-FRCNN.txt
# Finished val sequence MOT17-13-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C5_I0.1/MOT17-13-FRCNN.txt
# Finished val sequence MOT17-13-FRCNN -> SORT_outputs_MOT17/val_L10_A0.75_C5_I0.3/MOT17-13-FRCNN.txt
# split=val | L:10, A:0.9, C:2, I:0.05 -> HOTA: 0.439, IDF1: 0.445, MOTA: 0.323 (results in SORT_outputs_MOT17/val_L10_A0.9_C2_I0.05)
# split=val | L:10, A:0.9, C:2, I:0.1 -> HOTA: 0.442, IDF1: 0.446, MOTA: 0.324 (results in SORT_outputs_MOT17/val_L10_A0.9_C2_I0.1)
# split=val | L:10, A:0.9, C:2, I:0.3 -> HOTA: 0.447, IDF1: 0.456, MOTA: 0.325 (results in SORT_outputs_MOT17/val_L10_A0.9_C2_I0.3)
# split=val | L:10, A:0.9, C:2, I:0.7 -> HOTA: 0.434, IDF1: 0.434, MOTA: 0.309 (results in SORT_outputs_MOT17/val_L10_A0.9_C2_I0.7)
# split=val | L:10, A:0.9, C:2, I:0.5 -> HOTA: 0.445, IDF1: 0.450, MOTA: 0.323 (results in SORT_outputs_MOT17/val_L10_A0.9_C2_I0.5)
# Finished val sequence MOT17-02-FRCNN -> SORT_outputs_MOT17/val_L10_A0.9_C3_I0.05/MOT17-02-FRCNN.txt
# Finished val sequence MOT17-02-FRCNN -> SORT_outputs_MOT17/val_L10_A0.9_C3_I0.7/MOT17-02-FRCNN.txt
# ...
#
# Finished val sequence MOT17-09-FRCNN -> SORT_outputs_MOT17/val_L60_A0.9_C2_I0.3/MOT17-09-FRCNN.txt
# Finished val sequence MOT17-05-FRCNN -> SORT_outputs_MOT17/val_L60_A0.75_C5_I0.1/MOT17-05-FRCNN.txt
# Finished val sequence MOT17-05-FRCNN -> SORT_outputs_MOT17/val_L60_A0.75_C5_I0.05/MOT17-05-FRCNN.txtFinished val sequence MOT17-10-FRCNN -> SORT_outputs_MOT17/val_L60_A0.9_C2_I0.1/MOT17-10-FRCNN.txt
#
# Finished val sequence MOT17-11-FRCNN -> SORT_outputs_MOT17/val_L60_A0.9_C2_I0.5/MOT17-11-FRCNN.txt
# Finished val sequence MOT17-10-FRCNN -> SORT_outputs_MOT17/val_L60_A0.9_C2_I0.7/MOT17-10-FRCNN.txt
# Finished val sequence MOT17-09-FRCNN -> SORT_outputs_MOT17/val_L60_A0.75_C5_I0.3/MOT17-09-FRCNN.txt
# Finished val sequence MOT17-09-FRCNN -> SORT_outputs_MOT17/val_L60_A0.75_C5_I0.5/MOT17-09-FRCNN.txt
# Finished val sequence MOT17-10-FRCNN -> SORT_outputs_MOT17/val_L60_A0.9_C2_I0.3/MOT17-10-FRCNN.txt
# Finished val sequence MOT17-11-FRCNN -> SORT_outputs_MOT17/val_L60_A0.9_C2_I0.05/MOT17-11-FRCNN.txt
# Finished val sequence MOT17-09-FRCNN -> SORT_outputs_MOT17/val_L60_A0.75_C5_I0.1/MOT17-09-FRCNN.txtFinished val sequence MOT17-13-FRCNN -> SORT_outputs_MOT17/val_L60_A0.9_C2_I0.5/MOT17-13-FRCNN.txt
#
# Finished val sequence MOT17-09-FRCNN -> SORT_outputs_MOT17/val_L60_A0.75_C5_I0.05/MOT17-09-FRCNN.txt
# Finished val sequence MOT17-13-FRCNN -> SORT_outputs_MOT17/val_L60_A0.9_C2_I0.05/MOT17-13-FRCNN.txt
# Finished val sequence MOT17-11-FRCNN -> SORT_outputs_MOT17/val_L60_A0.9_C2_I0.1/MOT17-11-FRCNN.txt
# Finished val sequence MOT17-11-FRCNN -> SORT_outputs_MOT17/val_L60_A0.9_C2_I0.7/MOT17-11-FRCNN.txt
# Finished val sequence MOT17-11-FRCNN -> SORT_outputs_MOT17/val_L60_A0.9_C2_I0.3/MOT17-11-FRCNN.txt
# Finished val sequence MOT17-10-FRCNN -> SORT_outputs_MOT17/val_L60_A0.75_C5_I0.7/MOT17-10-FRCNN.txt
# Finished val sequence MOT17-13-FRCNN -> SORT_outputs_MOT17/val_L60_A0.9_C2_I0.7/MOT17-13-FRCNN.txt
# Finished val sequence MOT17-13-FRCNN -> SORT_outputs_MOT17/val_L60_A0.9_C2_I0.1/MOT17-13-FRCNN.txt
# Finished val sequence MOT17-10-FRCNN -> SORT_outputs_MOT17/val_L60_A0.75_C5_I0.5/MOT17-10-FRCNN.txt
# Finished val sequence MOT17-13-FRCNN -> SORT_outputs_MOT17/val_L60_A0.9_C2_I0.3/MOT17-13-FRCNN.txt
# Finished val sequence MOT17-10-FRCNN -> SORT_outputs_MOT17/val_L60_A0.75_C5_I0.3/MOT17-10-FRCNN.txt
# Finished val sequence MOT17-10-FRCNN -> SORT_outputs_MOT17/val_L60_A0.75_C5_I0.1/MOT17-10-FRCNN.txt
# Finished val sequence MOT17-10-FRCNN -> SORT_outputs_MOT17/val_L60_A0.75_C5_I0.05/MOT17-10-FRCNN.txt
# Finished val sequence MOT17-11-FRCNN -> SORT_outputs_MOT17/val_L60_A0.75_C5_I0.7/MOT17-11-FRCNN.txt
# Finished val sequence MOT17-11-FRCNN -> SORT_outputs_MOT17/val_L60_A0.75_C5_I0.5/MOT17-11-FRCNN.txt
# Finished val sequence MOT17-11-FRCNN -> SORT_outputs_MOT17/val_L60_A0.75_C5_I0.3/MOT17-11-FRCNN.txt
# Finished val sequence MOT17-13-FRCNN -> SORT_outputs_MOT17/val_L60_A0.75_C5_I0.7/MOT17-13-FRCNN.txt
# Finished val sequence MOT17-11-FRCNN -> SORT_outputs_MOT17/val_L60_A0.75_C5_I0.05/MOT17-11-FRCNN.txtFinished val sequence MOT17-11-FRCNN -> SORT_outputs_MOT17/val_L60_A0.75_C5_I0.1/MOT17-11-FRCNN.txt
#
# Finished val sequence MOT17-13-FRCNN -> SORT_outputs_MOT17/val_L60_A0.75_C5_I0.5/MOT17-13-FRCNN.txt
# Finished val sequence MOT17-13-FRCNN -> SORT_outputs_MOT17/val_L60_A0.75_C5_I0.3/MOT17-13-FRCNN.txt
# Finished val sequence MOT17-13-FRCNN -> SORT_outputs_MOT17/val_L60_A0.75_C5_I0.1/MOT17-13-FRCNN.txt
# Finished val sequence MOT17-13-FRCNN -> SORT_outputs_MOT17/val_L60_A0.75_C5_I0.05/MOT17-13-FRCNN.txt
# split=val | L:60, A:0.9, C:2, I:0.5 -> HOTA: 0.447, IDF1: 0.456, MOTA: 0.322 (results in SORT_outputs_MOT17/val_L60_A0.9_C2_I0.5)
# split=val | L:60, A:0.9, C:2, I:0.05 -> HOTA: 0.436, IDF1: 0.443, MOTA: 0.325 (results in SORT_outputs_MOT17/val_L60_A0.9_C2_I0.05)
# split=val | L:60, A:0.9, C:2, I:0.7 -> HOTA: 0.438, IDF1: 0.438, MOTA: 0.309 (results in SORT_outputs_MOT17/val_L60_A0.9_C2_I0.7)
# split=val | L:60, A:0.9, C:2, I:0.1 -> HOTA: 0.441, IDF1: 0.448, MOTA: 0.327 (results in SORT_outputs_MOT17/val_L60_A0.9_C2_I0.1)
# split=val | L:60, A:0.9, C:2, I:0.3 -> HOTA: 0.449, IDF1: 0.458, MOTA: 0.326 (results in SORT_outputs_MOT17/val_L60_A0.9_C2_I0.3)
# Finished val sequence MOT17-02-FRCNN -> SORT_outputs_MOT17/val_L60_A0.9_C3_I0.05/MOT17-02-FRCNN.txt
# Finished val sequence MOT17-02-FRCNN -> SORT_outputs_MOT17/val_L60_A0.9_C3_I0.3/MOT17-02-FRCNN.txtFinished val sequence MOT17-02-FRCNN -> SORT_outputs_MOT17/val_L60_A0.9_C3_I0.1/MOT17-02-FRCNN.txt
#
# Finished val sequence MOT17-02-FRCNN -> SORT_outputs_MOT17/val_L60_A0.9_C3_I0.7/MOT17-02-FRCNN.txt
# Finished val sequence MOT17-02-FRCNN -> SORT_outputs_MOT17/val_L60_A0.9_C3_I0.5/MOT17-02-FRCNN.txt
# split=val | L:60, A:0.75, C:5, I:0.7 -> HOTA: 0.476, IDF1: 0.495, MOTA: 0.399 (results in SORT_outputs_MOT17/val_L60_A0.75_C5_I0.7)
# split=val | L:60, A:0.75, C:5, I:0.5 -> HOTA: 0.486, IDF1: 0.517, MOTA: 0.401 (results in SORT_outputs_MOT17/val_L60_A0.75_C5_I0.5)
# split=val | L:60, A:0.75, C:5, I:0.3 -> HOTA: 0.483, IDF1: 0.514, MOTA: 0.382 (results in SORT_outputs_MOT17/val_L60_A0.75_C5_I0.3)
# Finished val sequence MOT17-02-FRCNN -> SORT_outputs_MOT17/val_L60_A0.9_C5_I0.05/MOT17-02-FRCNN.txt
# split=val | L:60, A:0.75, C:5, I:0.1 -> HOTA: 0.474, IDF1: 0.508, MOTA: 0.373 (results in SORT_outputs_MOT17/val_L60_A0.75_C5_I0.1)
# split=val | L:60, A:0.75, C:5, I:0.05 -> HOTA: 0.473, IDF1: 0.504, MOTA: 0.372 (results in SORT_outputs_MOT17/val_L60_A0.75_C5_I0.05)
# Finished val sequence MOT17-02-FRCNN -> SORT_outputs_MOT17/val_L60_A0.9_C5_I0.1/MOT17-02-FRCNN.txt
# [161/180] val combination finished.
# [162/180] val combination finished.
# [163/180] val combination finished.
# [164/180] val combination finished.
# [165/180] val combination finished.
# [166/180] val combination finished.
# [167/180] val combination finished.
# [168/180] val combination finished.
# [169/180] val combination finished.
# [170/180] val combination finished.
# Finished val sequence MOT17-02-FRCNN -> SORT_outputs_MOT17/val_L60_A0.9_C5_I0.3/MOT17-02-FRCNN.txt
# Finished val sequence MOT17-02-FRCNN -> SORT_outputs_MOT17/val_L60_A0.9_C5_I0.7/MOT17-02-FRCNN.txt
# Finished val sequence MOT17-02-FRCNN -> SORT_outputs_MOT17/val_L60_A0.9_C5_I0.5/MOT17-02-FRCNN.txt
# Finished val sequence MOT17-04-FRCNN -> SORT_outputs_MOT17/val_L60_A0.9_C3_I0.05/MOT17-04-FRCNN.txt
# Finished val sequence MOT17-04-FRCNN -> SORT_outputs_MOT17/val_L60_A0.9_C3_I0.3/MOT17-04-FRCNN.txt
# Finished val sequence MOT17-04-FRCNN -> SORT_outputs_MOT17/val_L60_A0.9_C3_I0.7/MOT17-04-FRCNN.txt
# Finished val sequence MOT17-04-FRCNN -> SORT_outputs_MOT17/val_L60_A0.9_C3_I0.1/MOT17-04-FRCNN.txt
# Finished val sequence MOT17-05-FRCNN -> SORT_outputs_MOT17/val_L60_A0.9_C3_I0.05/MOT17-05-FRCNN.txt
# Finished val sequence MOT17-05-FRCNN -> SORT_outputs_MOT17/val_L60_A0.9_C3_I0.3/MOT17-05-FRCNN.txtFinished val sequence MOT17-04-FRCNN -> SORT_outputs_MOT17/val_L60_A0.9_C3_I0.5/MOT17-04-FRCNN.txt
#
# Finished val sequence MOT17-05-FRCNN -> SORT_outputs_MOT17/val_L60_A0.9_C3_I0.7/MOT17-05-FRCNN.txt
# Finished val sequence MOT17-09-FRCNN -> SORT_outputs_MOT17/val_L60_A0.9_C3_I0.05/MOT17-09-FRCNN.txt
# Finished val sequence MOT17-05-FRCNN -> SORT_outputs_MOT17/val_L60_A0.9_C3_I0.1/MOT17-05-FRCNN.txt
# Finished val sequence MOT17-05-FRCNN -> SORT_outputs_MOT17/val_L60_A0.9_C3_I0.5/MOT17-05-FRCNN.txt
# Finished val sequence MOT17-09-FRCNN -> SORT_outputs_MOT17/val_L60_A0.9_C3_I0.3/MOT17-09-FRCNN.txt
# Finished val sequence MOT17-10-FRCNN -> SORT_outputs_MOT17/val_L60_A0.9_C3_I0.05/MOT17-10-FRCNN.txt
# Finished val sequence MOT17-09-FRCNN -> SORT_outputs_MOT17/val_L60_A0.9_C3_I0.7/MOT17-09-FRCNN.txt
# Finished val sequence MOT17-10-FRCNN -> SORT_outputs_MOT17/val_L60_A0.9_C3_I0.3/MOT17-10-FRCNN.txt
# Finished val sequence MOT17-09-FRCNN -> SORT_outputs_MOT17/val_L60_A0.9_C3_I0.1/MOT17-09-FRCNN.txt
# Finished val sequence MOT17-09-FRCNN -> SORT_outputs_MOT17/val_L60_A0.9_C3_I0.5/MOT17-09-FRCNN.txt
# Finished val sequence MOT17-10-FRCNN -> SORT_outputs_MOT17/val_L60_A0.9_C3_I0.7/MOT17-10-FRCNN.txt
# Finished val sequence MOT17-10-FRCNN -> SORT_outputs_MOT17/val_L60_A0.9_C3_I0.1/MOT17-10-FRCNN.txt
# Finished val sequence MOT17-04-FRCNN -> SORT_outputs_MOT17/val_L60_A0.9_C5_I0.05/MOT17-04-FRCNN.txt
# Finished val sequence MOT17-10-FRCNN -> SORT_outputs_MOT17/val_L60_A0.9_C3_I0.5/MOT17-10-FRCNN.txt
# Finished val sequence MOT17-11-FRCNN -> SORT_outputs_MOT17/val_L60_A0.9_C3_I0.05/MOT17-11-FRCNN.txt
# Finished val sequence MOT17-11-FRCNN -> SORT_outputs_MOT17/val_L60_A0.9_C3_I0.3/MOT17-11-FRCNN.txt
# Finished val sequence MOT17-11-FRCNN -> SORT_outputs_MOT17/val_L60_A0.9_C3_I0.7/MOT17-11-FRCNN.txt
# Finished val sequence MOT17-05-FRCNN -> SORT_outputs_MOT17/val_L60_A0.9_C5_I0.05/MOT17-05-FRCNN.txtFinished val sequence MOT17-13-FRCNN -> SORT_outputs_MOT17/val_L60_A0.9_C3_I0.05/MOT17-13-FRCNN.txt
#
# Finished val sequence MOT17-04-FRCNN -> SORT_outputs_MOT17/val_L60_A0.9_C5_I0.1/MOT17-04-FRCNN.txt
# Finished val sequence MOT17-11-FRCNN -> SORT_outputs_MOT17/val_L60_A0.9_C3_I0.1/MOT17-11-FRCNN.txt
# Finished val sequence MOT17-13-FRCNN -> SORT_outputs_MOT17/val_L60_A0.9_C3_I0.3/MOT17-13-FRCNN.txt
# Finished val sequence MOT17-13-FRCNN -> SORT_outputs_MOT17/val_L60_A0.9_C3_I0.7/MOT17-13-FRCNN.txt
# Finished val sequence MOT17-04-FRCNN -> SORT_outputs_MOT17/val_L60_A0.9_C5_I0.7/MOT17-04-FRCNN.txt
# Finished val sequence MOT17-11-FRCNN -> SORT_outputs_MOT17/val_L60_A0.9_C3_I0.5/MOT17-11-FRCNN.txt
# Finished val sequence MOT17-13-FRCNN -> SORT_outputs_MOT17/val_L60_A0.9_C3_I0.1/MOT17-13-FRCNN.txt
# Finished val sequence MOT17-04-FRCNN -> SORT_outputs_MOT17/val_L60_A0.9_C5_I0.5/MOT17-04-FRCNN.txt
# Finished val sequence MOT17-04-FRCNN -> SORT_outputs_MOT17/val_L60_A0.9_C5_I0.3/MOT17-04-FRCNN.txt
# Finished val sequence MOT17-09-FRCNN -> SORT_outputs_MOT17/val_L60_A0.9_C5_I0.05/MOT17-09-FRCNN.txt
# Finished val sequence MOT17-13-FRCNN -> SORT_outputs_MOT17/val_L60_A0.9_C3_I0.5/MOT17-13-FRCNN.txt
# Finished val sequence MOT17-05-FRCNN -> SORT_outputs_MOT17/val_L60_A0.9_C5_I0.1/MOT17-05-FRCNN.txt
# Finished val sequence MOT17-05-FRCNN -> SORT_outputs_MOT17/val_L60_A0.9_C5_I0.7/MOT17-05-FRCNN.txt
# Finished val sequence MOT17-10-FRCNN -> SORT_outputs_MOT17/val_L60_A0.9_C5_I0.05/MOT17-10-FRCNN.txt
# Finished val sequence MOT17-05-FRCNN -> SORT_outputs_MOT17/val_L60_A0.9_C5_I0.5/MOT17-05-FRCNN.txt
# Finished val sequence MOT17-05-FRCNN -> SORT_outputs_MOT17/val_L60_A0.9_C5_I0.3/MOT17-05-FRCNN.txt
# Finished val sequence MOT17-09-FRCNN -> SORT_outputs_MOT17/val_L60_A0.9_C5_I0.1/MOT17-09-FRCNN.txt
# Finished val sequence MOT17-09-FRCNN -> SORT_outputs_MOT17/val_L60_A0.9_C5_I0.7/MOT17-09-FRCNN.txt
# Finished val sequence MOT17-09-FRCNN -> SORT_outputs_MOT17/val_L60_A0.9_C5_I0.5/MOT17-09-FRCNN.txt
# Finished val sequence MOT17-09-FRCNN -> SORT_outputs_MOT17/val_L60_A0.9_C5_I0.3/MOT17-09-FRCNN.txt
# Finished val sequence MOT17-10-FRCNN -> SORT_outputs_MOT17/val_L60_A0.9_C5_I0.7/MOT17-10-FRCNN.txt
# Finished val sequence MOT17-10-FRCNN -> SORT_outputs_MOT17/val_L60_A0.9_C5_I0.1/MOT17-10-FRCNN.txt
# Finished val sequence MOT17-11-FRCNN -> SORT_outputs_MOT17/val_L60_A0.9_C5_I0.05/MOT17-11-FRCNN.txt
# Finished val sequence MOT17-10-FRCNN -> SORT_outputs_MOT17/val_L60_A0.9_C5_I0.5/MOT17-10-FRCNN.txt
# Finished val sequence MOT17-10-FRCNN -> SORT_outputs_MOT17/val_L60_A0.9_C5_I0.3/MOT17-10-FRCNN.txt
# Finished val sequence MOT17-13-FRCNN -> SORT_outputs_MOT17/val_L60_A0.9_C5_I0.05/MOT17-13-FRCNN.txt
# Finished val sequence MOT17-11-FRCNN -> SORT_outputs_MOT17/val_L60_A0.9_C5_I0.1/MOT17-11-FRCNN.txtFinished val sequence MOT17-11-FRCNN -> SORT_outputs_MOT17/val_L60_A0.9_C5_I0.7/MOT17-11-FRCNN.txt
#
# Finished val sequence MOT17-11-FRCNN -> SORT_outputs_MOT17/val_L60_A0.9_C5_I0.5/MOT17-11-FRCNN.txtFinished val sequence MOT17-11-FRCNN -> SORT_outputs_MOT17/val_L60_A0.9_C5_I0.3/MOT17-11-FRCNN.txt
#
# Finished val sequence MOT17-13-FRCNN -> SORT_outputs_MOT17/val_L60_A0.9_C5_I0.7/MOT17-13-FRCNN.txt
# Finished val sequence MOT17-13-FRCNN -> SORT_outputs_MOT17/val_L60_A0.9_C5_I0.1/MOT17-13-FRCNN.txt
# Finished val sequence MOT17-13-FRCNN -> SORT_outputs_MOT17/val_L60_A0.9_C5_I0.3/MOT17-13-FRCNN.txtFinished val sequence MOT17-13-FRCNN -> SORT_outputs_MOT17/val_L60_A0.9_C5_I0.5/MOT17-13-FRCNN.txt
#
# split=val | L:60, A:0.9, C:3, I:0.3 -> HOTA: 0.447, IDF1: 0.456, MOTA: 0.323 (results in SORT_outputs_MOT17/val_L60_A0.9_C3_I0.3)
# split=val | L:60, A:0.9, C:3, I:0.7 -> HOTA: 0.436, IDF1: 0.436, MOTA: 0.306 (results in SORT_outputs_MOT17/val_L60_A0.9_C3_I0.7)split=val | L:60, A:0.9, C:3, I:0.05 -> HOTA: 0.435, IDF1: 0.441, MOTA: 0.323 (results in SORT_outputs_MOT17/val_L60_A0.9_C3_I0.05)
#
# split=val | L:60, A:0.9, C:3, I:0.1 -> HOTA: 0.439, IDF1: 0.447, MOTA: 0.325 (results in SORT_outputs_MOT17/val_L60_A0.9_C3_I0.1)
# split=val | L:60, A:0.9, C:3, I:0.5 -> HOTA: 0.445, IDF1: 0.454, MOTA: 0.320 (results in SORT_outputs_MOT17/val_L60_A0.9_C3_I0.5)
# [171/180] val combination finished.
# [172/180] val combination finished.
# [173/180] val combination finished.
# [174/180] val combination finished.
# [175/180] val combination finished.
# split=val | L:60, A:0.9, C:5, I:0.05 -> HOTA: 0.431, IDF1: 0.437, MOTA: 0.319 (results in SORT_outputs_MOT17/val_L60_A0.9_C5_I0.05)
# split=val | L:60, A:0.9, C:5, I:0.7 -> HOTA: 0.432, IDF1: 0.432, MOTA: 0.301 (results in SORT_outputs_MOT17/val_L60_A0.9_C5_I0.7)
# split=val | L:60, A:0.9, C:5, I:0.3 -> HOTA: 0.443, IDF1: 0.453, MOTA: 0.320 (results in SORT_outputs_MOT17/val_L60_A0.9_C5_I0.3)
# split=val | L:60, A:0.9, C:5, I:0.5 -> HOTA: 0.441, IDF1: 0.451, MOTA: 0.316 (results in SORT_outputs_MOT17/val_L60_A0.9_C5_I0.5)
# [176/180] val combination finished.
# split=val | L:60, A:0.9, C:5, I:0.1 -> HOTA: 0.436, IDF1: 0.442, MOTA: 0.320 (results in SORT_outputs_MOT17/val_L60_A0.9_C5_I0.1)
# [177/180] val combination finished.
# [178/180] val combination finished.
# [179/180] val combination finished.
# [180/180] val combination finished.
# Validation hyperparameter sweep complete. Results stored in 'sort_MOT17_val_tuning_df'.
#   split  lost_track_buffer  track_activation_threshold  \
# 0   val                 10                        0.25
# 1   val                 10                        0.25
# 2   val                 10                        0.25
# 3   val                 10                        0.25
# 4   val                 10                        0.25
#
#    minimum_consecutive_frames  minimum_iou_threshold      HOTA      IDF1  \
# 0                           2                   0.05  0.459556  0.470605
# 1                           2                   0.10  0.459330  0.471068
# 2                           2                   0.30  0.468628  0.477444
# 3                           2                   0.50  0.472178  0.480560
# 4                           2                   0.70  0.469326  0.468055
#
#        MOTA                                 output_dir
# 0  0.269691  SORT_outputs_MOT17/val_L10_A0.25_C2_I0.05
# 1  0.273107   SORT_outputs_MOT17/val_L10_A0.25_C2_I0.1
# 2  0.302565   SORT_outputs_MOT17/val_L10_A0.25_C2_I0.3
# 3  0.330885   SORT_outputs_MOT17/val_L10_A0.25_C2_I0.5
# 4  0.370201   SORT_outputs_MOT17/val_L10_A0.25_C2_I0.7
#
# Best validation row by HOTA:
#  split                                                              val
# lost_track_buffer                                                   10
# track_activation_threshold                                        0.75
# minimum_consecutive_frames                                           2
# minimum_iou_threshold                                              0.3
# HOTA                                                          0.492734
# IDF1                                                          0.522306
# MOTA                                                          0.399588
# output_dir                    SORT_outputs_MOT17/val_L10_A0.75_C2_I0.3
# Name: 32, dtype: object
#
# Best hyperparameters (val): {'lost_track_buffer': 10, 'track_activation_threshold': 0.75, 'minimum_consecutive_frames': 2, 'minimum_iou_threshold': 0.3}

# %%
# Final MOT17-test run with best SORT hyperparameters (if available)

if "best_params" in globals():
    print("Using MOT17-test SORT hyperparameters:", best_params)

    test_result = run_sort_mot17_once(
        split="test",
        **best_params,
    )

    print("\nTest split metrics (if GT available):")
    print({k: test_result.get(k) for k in ["HOTA", "IDF1", "MOTA"]})

    # Create a zip archive of the test outputs for submission
    submission_dir = test_result["output_dir"]
    submission_zip_base = os.path.basename(submission_dir)
    submission_zip = "SORT_" + submission_zip_base + ".zip"
    shutil.make_archive("SORT_" + submission_zip_base, "zip", submission_dir)
    print("\nCreated MOT17 submission archive:", submission_zip)
    print("Archive contains MOT17 server-format txt files ready for upload.")
else:
    print("No best_params found – run the validation sweep cell first.")
# Out:
# Using MOT17-test SORT hyperparameters: {'lost_track_buffer': 10, 'track_activation_threshold': 0.75, 'minimum_consecutive_frames': 2, 'minimum_iou_threshold': 0.3}
# Finished test sequence MOT17-01 -> SORT_outputs_MOT17/test_L10_A0.75_C2_I0.3/MOT17-01.txt
# Finished test sequence MOT17-03 -> SORT_outputs_MOT17/test_L10_A0.75_C2_I0.3/MOT17-03.txt
# Finished test sequence MOT17-06 -> SORT_outputs_MOT17/test_L10_A0.75_C2_I0.3/MOT17-06.txt
# Finished test sequence MOT17-07 -> SORT_outputs_MOT17/test_L10_A0.75_C2_I0.3/MOT17-07.txt
# Finished test sequence MOT17-08 -> SORT_outputs_MOT17/test_L10_A0.75_C2_I0.3/MOT17-08.txt
# Finished test sequence MOT17-12 -> SORT_outputs_MOT17/test_L10_A0.75_C2_I0.3/MOT17-12.txt
# Finished test sequence MOT17-14 -> SORT_outputs_MOT17/test_L10_A0.75_C2_I0.3/MOT17-14.txt
# Replicated + removed: MOT17-01.txt
# Replicated + removed: MOT17-03.txt
# Replicated + removed: MOT17-06.txt
# Replicated + removed: MOT17-07.txt
# Replicated + removed: MOT17-08.txt
# Replicated + removed: MOT17-12.txt
# Replicated + removed: MOT17-14.txt
# Empty MOT17 server files created for missing sequences.
#
# Test split metrics (if GT available):
# {'HOTA': None, 'IDF1': None, 'MOTA': None}
#
# Created MOT17 submission archive: SORT_test_L10_A0.75_C2_I0.3.zip
# Archive contains MOT17 server-format txt files ready for upload.
